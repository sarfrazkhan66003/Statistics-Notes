# %%
data = [2, 3, 4, 5, 8, 9, 12, 40, 41, 15]

# %%
data
# Out:
# [2, 3, 4, 5, 8, 9, 12, 40, 41, 15]

# %%
#range
max(data) - min(data)
# Out:
# 39

# %%
import numpy as np

# %%
np.percentile(data, [0, 25, 50, 75, 100])
# Out:
# array([ 2.  ,  4.25,  8.5 , 14.25, 41.  ])

# %%
#IQR > Q3-Q1
12-4
# Out:
# 8

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.boxplot(data) #upper fence = Q3+1.5*IQR, #LOWER fence = Q1-1.5*IQR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.boxplot(data) #upper fence = Q3+1.5*IQR, #LOWER fence = Q1-1.5*IQR
#
# NameError: name 'sns' is not defined

# %%
#VARIANCE
np.var(data)
# Out:
# 191.69000000000003

# %%
#std deviation
np.std(data)
# Out:
# 13.8452157801892

# %%
import statistics

# %%
statistics.variance(data) #sample var denominator > n-1
# Out:
# 212.98888888888888

# %%
statistics.pvariance(data)
# Out:
# 191.69
